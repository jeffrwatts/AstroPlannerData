# %%
# Cell 1 — Object list (primary input)
# This is the only cell that needs editing to add a new object.
# objectId, displayName, and recommended are bootstrapped from dso.json.

objects = [
    {"objectId": "ngc869",      "displayName": "Double Cluster (NGC 869 & 884)",        "recommended": True},
    {"objectId": "leotriplet",  "displayName": "Leo Triplet",                           "recommended": True},
    {"objectId": "markarian",   "displayName": "Markarian's Chain",                     "recommended": True},
    {"objectId": "m81m82",      "displayName": "Bode's and Cigar Galaxies",             "recommended": True},
    {"objectId": "ngc3628",     "displayName": "Hamburger Galaxy",                      "recommended": True},
    {"objectId": "abell1060",   "displayName": "The Hydra Cluster (Abell 1060)",        "recommended": True},
    {"objectId": "m106ngc4217", "displayName": "M106 with NGC 4217",                    "recommended": True},
    {"objectId": "whalehockey", "displayName": "Whale (NGC 4631) & Hockey Stick (NGC 4656)", "recommended": True},
    {"objectId": "ngc3166",     "displayName": "NGC 3166/3169 Group",                   "recommended": True},
    {"objectId": "ngc5363",     "displayName": "NGC 5363/5364 Group",                   "recommended": True},  
    {"objectId": "ngc4565",     "displayName": "Needle Galaxy",                         "recommended": True},
    {"objectId": "ngc5101",     "displayName": "NGC 5101",                              "recommended": True},
    {"objectId": "ngc5139",     "displayName": "Omega Centauri",                        "recommended": True},
    {"objectId": "ngc6726",     "displayName": "Corona Australis Molecular Cloud",      "recommended": True},
    {"objectId": "ngc6960",     "displayName": "Western Veil Nebula",                   "recommended": True},
    {"objectId": "ngc6992",     "displayName": "Eastern Veil Nebula",                   "recommended": True},
    {"objectId": "ngc6979",     "displayName": "Pickering Triangle",                    "recommended": True},
    {"objectId": "ngc2237",     "displayName": "Rosette Nebula",                        "recommended": True},
    {"objectId": "ngc7293",     "displayName": "Helix Nebula",                          "recommended": True},
    {"objectId": "ic434",       "displayName": "Horsehead Nebula",                      "recommended": True},
    {"objectId": "ngc6888",     "displayName": "Crescent Nebula",                       "recommended": True},
    {"objectId": "ic5146",      "displayName": "Cocoon Nebula",                         "recommended": True},
    {"objectId": "ngc1977",     "displayName": "Running Man Nebula",                    "recommended": True},
    {"objectId": "ngc1499",     "displayName": "California Nebula",                     "recommended": True},
    {"objectId": "ngc2264",     "displayName": "Christmas Tree Cluster & Cone Nebula",  "recommended": True},
    {"objectId": "ic410",       "displayName": "Tadpoles Nebula",                       "recommended": True},
    {"objectId": "ic405",       "displayName": "Flaming Star Nebula",                   "recommended": True},
    {"objectId": "ngc281",      "displayName": "Pacman Nebula",                         "recommended": True},
    {"objectId": "ngc7380",     "displayName": "Wizard Nebula",                         "recommended": True},
    {"objectId": "ngc7000",     "displayName": "North America Nebula",                  "recommended": True},
    {"objectId": "ngc2359",     "displayName": "Thor's Helmet",                         "recommended": True},
    {"objectId": "ic1805",      "displayName": "Heart Nebula",                          "recommended": True},
    {"objectId": "ic1848",      "displayName": "Soul Nebula",                           "recommended": True},
    {"objectId": "sh2-261",     "displayName": "Lower's Nebula",                        "recommended": True},
    {"objectId": "sh2-112",     "displayName": "Sh2-112",                               "recommended": True},
    {"objectId": "ngc6823",     "displayName": "NGC 6823 (Sh2-86)",                     "recommended": True},
    {"objectId": "sh2-101",     "displayName": "Tulip Nebula",                          "recommended": True},
    {"objectId": "ngc7822",     "displayName": "Question Mark Nebula",                  "recommended": True},
    {"objectId": "sh2-157",     "displayName": "Lobster Claw Nebula",                   "recommended": True},
    {"objectId": "sh2-155",     "displayName": "Cave Nebula (Caldwell9)",               "recommended": True},
    {"objectId": "sh2-132",     "displayName": "Lion Nebula",                           "recommended": True},
    {"objectId": "ic2177",      "displayName": "Seagull Nebula",                        "recommended": True},
    {"objectId": "ic443",       "displayName": "Jellyfish Nebula",                      "recommended": True},
    {"objectId": "sh2-308",     "displayName": "Dolphin Head Nebula",                   "recommended": True},
    {"objectId": "ngc7635",     "displayName": "Bubble Nebula",                         "recommended": True},
    {"objectId": "ic5070",      "displayName": "Pelican Nebula",                        "recommended": True},
    {"objectId": "ic1318",      "displayName": "Sadr Region / Crescent area (IC 1318)", "recommended": True},
    {"objectId": "ic1396",      "displayName": "Elephant Trunk Nebula",                 "recommended": True},
    {"objectId": "wr134",       "displayName": "WR 134",                                "recommended": True},
    {"objectId": "ic2118",      "displayName": "Witch Head Nebula",                     "recommended": True},
    {"objectId": "ngc7023",     "displayName": "Iris Nebula",                           "recommended": True},
    {"objectId": "ngc1333",     "displayName": "Embryo Nebula",                         "recommended": True},
    {"objectId": "ngc2467",     "displayName": "Skull and Crossbones Nebula",           "recommended": True},
    {"objectId": "ngc2174",     "displayName": "Monkey Head Nebula",                    "recommended": True},
    {"objectId": "sh2-223",     "displayName": "Sh2-223",                               "recommended": True},
    {"objectId": "sh2-224",     "displayName": "Sh2-224",                               "recommended": True},
    {"objectId": "sh2-274",     "displayName": "Medusa Nebula",                         "recommended": True},
    {"objectId": "sh2-188",     "displayName": "Shrimp Nebula",                         "recommended": True},
    {"objectId": "sh2-240",     "displayName": "Spaghetti Nebula",                      "recommended": True},
    {"objectId": "ngc6946",     "displayName": "Fireworks Galaxy",                      "recommended": True},
    {"objectId": "ngc3242",     "displayName": "Ghost of Jupiter",                      "recommended": True},
    {"objectId": "ngc1365",     "displayName": "Great Barred Spiral Galaxy",            "recommended": True},
    {"objectId": "ngc3372",     "displayName": "Carina Nebula",                         "recommended": True},
    {"objectId": "barnard72",   "displayName": "Snake Nebula",                          "recommended": True},
    {"objectId": "rhoophiuchi", "displayName": "Rho Ophiuchi Complex",                  "recommended": True},
    {"objectId": "ldn1082",     "displayName": "Seahorse Nebula",                       "recommended": True},
    {"objectId": "m1",          "displayName": "Crab Nebula",                           "recommended": True},
    {"objectId": "m2",          "displayName": "M2",                                    "recommended": False},
    {"objectId": "m3",          "displayName": "M3",                                    "recommended": True},
    {"objectId": "m4",          "displayName": "M4",                                    "recommended": False},
    {"objectId": "m5",          "displayName": "M5",                                    "recommended": False},
    {"objectId": "m6",          "displayName": "Butterfly Cluster",                     "recommended": False},
    {"objectId": "m7",          "displayName": "Ptolemy Cluster",                       "recommended": False},
    {"objectId": "m8",          "displayName": "Lagoon Nebula",                         "recommended": True},
    {"objectId": "m9",          "displayName": "M9",                                    "recommended": False},
    {"objectId": "m10",         "displayName": "M10",                                   "recommended": False},
    {"objectId": "m11",         "displayName": "Wild Duck Cluster",                     "recommended": False},
    {"objectId": "m12",         "displayName": "M12",                                   "recommended": False},
    {"objectId": "m13",         "displayName": "Hercules Cluster",                      "recommended": True},
    {"objectId": "m14",         "displayName": "M14",                                   "recommended": False},
    {"objectId": "m15",         "displayName": "M15",                                   "recommended": False},
    {"objectId": "m16",         "displayName": "Eagle Nebula",                          "recommended": True},
    {"objectId": "m17",         "displayName": "Omega Nebula",                          "recommended": True},
    {"objectId": "m18",         "displayName": "M18",                                   "recommended": False},
    {"objectId": "m19",         "displayName": "M19",                                   "recommended": False},
    {"objectId": "m20",         "displayName": "Trifid Nebula",                         "recommended": True},
    {"objectId": "m21",         "displayName": "M21",                                   "recommended": False},
    {"objectId": "m22",         "displayName": "M22",                                   "recommended": False},
    {"objectId": "m23",         "displayName": "M23",                                   "recommended": False},
    {"objectId": "m24",         "displayName": "Sagittarius Star Cloud",                "recommended": False},
    {"objectId": "m25",         "displayName": "M25",                                   "recommended": False},
    {"objectId": "m26",         "displayName": "M26",                                   "recommended": False},
    {"objectId": "m27",         "displayName": "Dumbbell Nebula",                       "recommended": True},
    {"objectId": "m28",         "displayName": "M28",                                   "recommended": False},
    {"objectId": "m29",         "displayName": "M29",                                   "recommended": False},
    {"objectId": "m30",         "displayName": "M30",                                   "recommended": False},
    {"objectId": "m31",         "displayName": "Andromeda Galaxy",                      "recommended": True},
    {"objectId": "m32",         "displayName": "M32",                                   "recommended": False},
    {"objectId": "m33",         "displayName": "Triangulum Galaxy",                     "recommended": True},
    {"objectId": "m34",         "displayName": "M34",                                   "recommended": False},
    {"objectId": "m35",         "displayName": "M35",                                   "recommended": False},
    {"objectId": "m36",         "displayName": "M36",                                   "recommended": False},
    {"objectId": "m37",         "displayName": "M37",                                   "recommended": False},
    {"objectId": "m38",         "displayName": "M38",                                   "recommended": False},
    {"objectId": "m39",         "displayName": "M39",                                   "recommended": False},
    {"objectId": "m40",         "displayName": "Winnecke 4",                            "recommended": False},
    {"objectId": "m41",         "displayName": "M41",                                   "recommended": False},
    {"objectId": "m42",         "displayName": "Orion Nebula",                          "recommended": True},
    {"objectId": "m43",         "displayName": "De Mairan's Nebula",                    "recommended": False},
    {"objectId": "m44",         "displayName": "Beehive Cluster",                       "recommended": False},
    {"objectId": "m45",         "displayName": "Pleiades",                              "recommended": True},
    {"objectId": "m46",         "displayName": "M46",                                   "recommended": False},
    {"objectId": "m47",         "displayName": "M47",                                   "recommended": False},
    {"objectId": "m48",         "displayName": "M48",                                   "recommended": False},
    {"objectId": "m49",         "displayName": "M49",                                   "recommended": False},
    {"objectId": "m50",         "displayName": "M50",                                   "recommended": False},
    {"objectId": "m51",         "displayName": "Whirlpool Galaxy",                      "recommended": True},
    {"objectId": "m52",         "displayName": "M52",                                   "recommended": False},
    {"objectId": "m53",         "displayName": "M53",                                   "recommended": False},
    {"objectId": "m54",         "displayName": "M54",                                   "recommended": False},
    {"objectId": "m55",         "displayName": "M55",                                   "recommended": False},
    {"objectId": "m56",         "displayName": "M56",                                   "recommended": False},
    {"objectId": "m57",         "displayName": "Ring Nebula",                           "recommended": True},
    {"objectId": "m58",         "displayName": "M58",                                   "recommended": False},
    {"objectId": "m59",         "displayName": "M59",                                   "recommended": False},
    {"objectId": "m60",         "displayName": "M60",                                   "recommended": False},
    {"objectId": "m61",         "displayName": "M61",                                   "recommended": False},
    {"objectId": "m62",         "displayName": "M62",                                   "recommended": False},
    {"objectId": "m63",         "displayName": "Sunflower Galaxy",                      "recommended": True},
    {"objectId": "m64",         "displayName": "Black Eye Galaxy",                      "recommended": True},
    {"objectId": "m65",         "displayName": "M65",                                   "recommended": False},
    {"objectId": "m66",         "displayName": "M66",                                   "recommended": False},
    {"objectId": "m67",         "displayName": "M67",                                   "recommended": False},
    {"objectId": "m68",         "displayName": "M68",                                   "recommended": False},
    {"objectId": "m69",         "displayName": "M69",                                   "recommended": False},
    {"objectId": "m70",         "displayName": "M70",                                   "recommended": False},
    {"objectId": "m71",         "displayName": "M71",                                   "recommended": False},
    {"objectId": "m72",         "displayName": "M72",                                   "recommended": False},
    {"objectId": "m73",         "displayName": "M73",                                   "recommended": False},
    {"objectId": "m74",         "displayName": "Phantom Galaxy",                        "recommended": False},
    {"objectId": "m75",         "displayName": "M75",                                   "recommended": False},
    {"objectId": "m76",         "displayName": "Little Dumbbell Nebula",                "recommended": False},
    {"objectId": "m77",         "displayName": "M77",                                   "recommended": False},
    {"objectId": "m78",         "displayName": "M78",                                   "recommended": True},
    {"objectId": "m79",         "displayName": "M79",                                   "recommended": False},
    {"objectId": "m80",         "displayName": "M80",                                   "recommended": False},
    {"objectId": "m81",         "displayName": "Bode's Galaxy",                         "recommended": True},
    {"objectId": "m82",         "displayName": "Cigar Galaxy",                          "recommended": True},
    {"objectId": "m83",         "displayName": "Southern Pinwheel Galaxy",              "recommended": True},
    {"objectId": "m84",         "displayName": "M84",                                   "recommended": False},
    {"objectId": "m85",         "displayName": "M85",                                   "recommended": False},
    {"objectId": "m86",         "displayName": "M86",                                   "recommended": False},
    {"objectId": "m87",         "displayName": "Virgo A",                               "recommended": False},
    {"objectId": "m88",         "displayName": "M88",                                   "recommended": True},
    {"objectId": "m89",         "displayName": "M89",                                   "recommended": False},
    {"objectId": "m90",         "displayName": "M90",                                   "recommended": False},
    {"objectId": "m91",         "displayName": "M91",                                   "recommended": False},
    {"objectId": "m92",         "displayName": "M92",                                   "recommended": False},
    {"objectId": "m93",         "displayName": "M93",                                   "recommended": False},
    {"objectId": "m94",         "displayName": "M94",                                   "recommended": True},
    {"objectId": "m95",         "displayName": "M95",                                   "recommended": False},
    {"objectId": "m96",         "displayName": "M96",                                   "recommended": False},
    {"objectId": "m97",         "displayName": "Owl Nebula",                            "recommended": True},
    {"objectId": "m98",         "displayName": "M98",                                   "recommended": False},
    {"objectId": "m99",         "displayName": "M99",                                   "recommended": False},
    {"objectId": "m100",        "displayName": "M100",                                  "recommended": False},
    {"objectId": "m101",        "displayName": "Pinwheel Galaxy",                       "recommended": True},
    {"objectId": "m102",        "displayName": "Spindle Galaxy",                        "recommended": False},
    {"objectId": "m103",        "displayName": "M103",                                  "recommended": False},
    {"objectId": "m104",        "displayName": "Sombrero Galaxy",                       "recommended": True},
    {"objectId": "m105",        "displayName": "M105",                                  "recommended": False},
    {"objectId": "m106",        "displayName": "M106",                                  "recommended": False},
    {"objectId": "m107",        "displayName": "M107",                                  "recommended": False},
    {"objectId": "m108",        "displayName": "M108",                                  "recommended": False},
    {"objectId": "m109",        "displayName": "M109",                                  "recommended": False},
    {"objectId": "m110",        "displayName": "M110",                                  "recommended": False},
]

# %%
# Cell 2 — Imports & config

import json
import re
import pandas as pd
import urllib.request
import io
from astroquery.simbad import Simbad
from astropy.coordinates import SkyCoord, get_constellation
import astropy.units as u

OPENGC_CSV_URL = "https://raw.githubusercontent.com/mattiaverga/OpenNGC/master/database_files/NGC.csv"
OUTPUT_FILE = "mobile/dso.json"

# %%
# Cell 3 — Lookup maps

# subType → type (must match ObjectType enum in AstroPlanner)
SUBTYPE_TO_TYPE = {
    "Emission Nebula":      "nebula",
    "Reflection Nebula":    "nebula",
    "Planetary Nebula":     "nebula",
    "Supernova Remnant":    "nebula",
    "Dark Nebula":          "nebula",
    "HII Ionized region":   "nebula",
    "Spiral Galaxy":        "galaxy",
    "Barred Spiral Galaxy": "galaxy",
    "Elliptical Galaxy":    "galaxy",
    "Lenticular Galaxy":    "galaxy",
    "Irregular Galaxy":     "galaxy",
    "Dwarf Galaxy":         "galaxy",
    "Interacting Galaxies": "galaxy",
    "Galaxy Group":         "galaxy",
    "Cluster of Galaxies":  "galaxy",
    "Open Cluster":         "cluster",
    "Globular Cluster":     "cluster",
    "Star Cloud":           "cluster",
    "Asterism":             "cluster",
    "Double Star":          "star",
}

# IAU 3-letter abbreviation → full constellation name
CONSTELLATION_NAMES = {
    "And": "Andromeda",       "Ant": "Antlia",          "Aps": "Apus",
    "Aqr": "Aquarius",        "Aql": "Aquila",           "Ara": "Ara",
    "Ari": "Aries",           "Aur": "Auriga",           "Boo": "Boötes",
    "Cae": "Caelum",          "Cam": "Camelopardalis",   "Cnc": "Cancer",
    "CVn": "Canes Venatici",  "CMa": "Canis Major",      "CMi": "Canis Minor",
    "Cap": "Capricornus",     "Car": "Carina",            "Cas": "Cassiopeia",
    "Cen": "Centaurus",       "Cep": "Cepheus",          "Cet": "Cetus",
    "Cha": "Chamaeleon",      "Cir": "Circinus",         "Col": "Columba",
    "Com": "Coma Berenices",  "CrA": "Corona Australis", "CrB": "Corona Borealis",
    "Crv": "Corvus",          "Crt": "Crater",            "Cru": "Crux",
    "Cyg": "Cygnus",          "Del": "Delphinus",        "Dor": "Dorado",
    "Dra": "Draco",           "Equ": "Equuleus",         "Eri": "Eridanus",
    "For": "Fornax",          "Gem": "Gemini",            "Gru": "Grus",
    "Her": "Hercules",        "Hor": "Horologium",       "Hya": "Hydra",
    "Hyi": "Hydrus",          "Ind": "Indus",             "Lac": "Lacerta",
    "Leo": "Leo",             "LMi": "Leo Minor",         "Lep": "Lepus",
    "Lib": "Libra",           "Lup": "Lupus",             "Lyn": "Lynx",
    "Lyr": "Lyra",            "Men": "Mensa",             "Mic": "Microscopium",
    "Mon": "Monoceros",       "Mus": "Musca",             "Nor": "Norma",
    "Oct": "Octans",          "Oph": "Ophiuchus",         "Ori": "Orion",
    "Pav": "Pavo",            "Peg": "Pegasus",           "Per": "Perseus",
    "Phe": "Phoenix",         "Pic": "Pictor",            "Psc": "Pisces",
    "PsA": "Piscis Austrinus","Pup": "Puppis",            "Pyx": "Pyxis",
    "Ret": "Reticulum",       "Sge": "Sagitta",           "Sgr": "Sagittarius",
    "Sco": "Scorpius",        "Scl": "Sculptor",          "Sct": "Scutum",
    "Se1": "Serpens Caput",   "Se2": "Serpens Cauda",     "Ser": "Serpens",
    "Sex": "Sextans",         "Tau": "Taurus",            "Tel": "Telescopium",
    "Tri": "Triangulum",      "TrA": "Triangulum Australe","Tuc": "Tucana",
    "UMa": "Ursa Major",      "UMi": "Ursa Minor",        "Vel": "Vela",
    "Vir": "Virgo",           "Vol": "Volans",            "Vul": "Vulpecula",
}

# %%
# Cell 4 — subType overrides
# objectId → subType for cases where the data source classification is wrong.
# type is always derived from the (possibly overridden) subType.

SUBTYPE_OVERRIDES = {
    # OpenNGC misclassifications
    "ngc1499":  "Emission Nebula",   # California Nebula
    "m40":      "Double Star",       # SIMBAD returns type "?" for Winnecke 4
    "ic2118":   "Reflection Nebula", # OpenNGC type=Dup; Witch Head Nebula is a reflection nebula

    # OpenNGC classifies the embedded cluster; we want the nebula (astrophotography context)
    "m42":      "Emission Nebula",   # Orion Nebula
    "m45":      "Reflection Nebula", # Pleiades is technically a star cluster but also known for its blue reflection nebula.
    "ic1805":   "Emission Nebula",   # Heart Nebula
    "ic1848":   "Emission Nebula",   # Soul Nebula
    "ic5146":   "Emission Nebula",   # Cocoon Nebula
    "ngc2264":  "Emission Nebula",   # Cone Nebula
    "ngc1977":  "Reflection Nebula", # Running Man Nebula
    "ngc1333":  "Reflection Nebula", # Embryo Nebula
    "ngc2467":  "Emission Nebula",   # Skull and Crossbones Nebula
    "ngc6823":  "Emission Nebula",   # NGC 6823 / Sh2-86
    "ngc7380":  "Emission Nebula",   # Wizard Nebula
    "ic1318":   "Emission Nebula",   # Sadr Region (SIMBAD returns Double Star for the central star)
    "ic1396":   "Emission Nebula",   # Elephant's Trunk
}

# %%
# Cell 5 — Data source lookup (OpenNGC)
# Fetches RA, Dec, constellation, subType, magnitude, and angular size from OpenNGC CSV.
# Raw lookup results only — overrides are not applied here.

def parse_ra_degrees(ra_str):
    """Convert RA from HH:MM:SS.ss to decimal degrees."""
    if not ra_str or ra_str.strip() == "":
        return None
    parts = ra_str.strip().split(":")
    h, m, s = float(parts[0]), float(parts[1]), float(parts[2])
    return round((h + m / 60 + s / 3600) * 15, 7)


def parse_dec_degrees(dec_str):
    """Convert Dec from +DD:MM:SS.ss to decimal degrees."""
    if not dec_str or dec_str.strip() == "":
        return None
    sign = -1 if dec_str.strip().startswith("-") else 1
    parts = dec_str.strip().lstrip("+-").split(":")
    d, m, s = float(parts[0]), float(parts[1]), float(parts[2])
    return round(sign * (d + m / 60 + s / 3600), 7)


def object_id_to_opengc_name(object_id):
    """Convert an objectId to the OpenNGC Name field format.
    Examples: ngc869 → NGC0869, ic434 → IC0434
    Returns None for Messier, Sharpless, Barnard, and custom IDs.
    """
    oid = object_id.lower()
    if oid.startswith("ngc"):
        return f"NGC{int(oid[3:]):04d}"
    elif oid.startswith("ic"):
        return f"IC{int(oid[2:]):04d}"
    return None


# OpenNGC type codes → clean subType strings
OPENGC_TYPE_MAP = {
    # Galaxies
    "G":      "Spiral Galaxy",
    "GX":     "Spiral Galaxy",
    "E":      "Elliptical Galaxy",
    "S":      "Spiral Galaxy",
    "S0":     "Lenticular Galaxy",
    "SA":     "Spiral Galaxy",
    "SAB":    "Spiral Galaxy",
    "SB":     "Barred Spiral Galaxy",
    "Irr":    "Irregular Galaxy",
    "dE":     "Dwarf Galaxy",
    "GGroup": "Spiral Galaxy",
    "GPair":  "Spiral Galaxy",
    "GTrpl":  "Spiral Galaxy",
    # Nebulae
    "EN":     "Emission Nebula",
    "RN":     "Reflection Nebula",
    "PN":     "Planetary Nebula",
    "SNR":    "Supernova Remnant",
    "DN":     "Dark Nebula",
    "HII":    "HII Ionized region",
    "ER":     "Emission Nebula",     # emission/reflection → emission
    "EmN":    "Emission Nebula",
    "RfN":    "Reflection Nebula",
    "Neb":    "Emission Nebula",     # generic nebula — override individually if reflection
    # Clusters
    "OC":     "Open Cluster",
    "OCl":    "Open Cluster",
    "GC":     "Globular Cluster",
    "GCl":    "Globular Cluster",
    "Cl+N":   "Open Cluster",
    "SC":     "Star Cloud",
    "Ast":    "Asterism",
    "*Ass":   "Star Cloud",          # stellar association (e.g. M24 Sagittarius Star Cloud)
    "Other":  "Asterism",            # catch-all for miscellaneous (e.g. M73)
    # Stars
    "DS":     "Double Star",
    "*":      "Double Star",
    "**":     "Double Star",
    # Duplicate entries — no type; handled via subType override in Cell 4
    "Dup":    None,
}


# Load OpenNGC CSV
with urllib.request.urlopen(OPENGC_CSV_URL) as response:
    csv_text = response.read().decode("utf-8")

opengc_df = pd.read_csv(io.StringIO(csv_text), sep=";", dtype=str, keep_default_na=False)
opengc_df.columns = opengc_df.columns.str.strip()

# Primary lookup: NGC/IC name → row (e.g. "NGC0869")
opengc_lookup = {row["Name"].strip(): row for _, row in opengc_df.iterrows()}

# Secondary lookup: Messier number (int) → row via the "M" column
messier_lookup = {}
for _, row in opengc_df.iterrows():
    m_val = row.get("M", "").strip()
    if m_val:
        try:
            messier_lookup[int(m_val)] = row
        except ValueError:
            pass

print(f"OpenNGC loaded: {len(opengc_df)} entries")
print(f"Messier entries indexed: {len(messier_lookup)}")
# Out:
# OpenNGC loaded: 13970 entries
# Messier entries indexed: 107

# %%
# Cell 5c — SIMBAD fallback lookup
# Used for any objectId that OpenNGC cannot resolve (Sharpless, Barnard, LDN, etc.)

import time

# Only request otype — adding magnitude fields (V, B) causes SIMBAD to drop
# objects that have no magnitude entry (most nebulae), returning zero results.
_simbad = Simbad()
_simbad.add_votable_fields("otype")
_simbad.TIMEOUT = 20   # seconds per request

# Map SIMBAD object type codes → our subType strings
SIMBAD_TYPE_MAP = {
    # Nebulae
    "HII":    "Emission Nebula",
    "EmO":    "Emission Nebula",
    "Neb":    "Emission Nebula",
    "WR*":    "Emission Nebula",    # Wolf-Rayet bubble (e.g. Sh2-308)
    "RNe":    "Reflection Nebula",
    "DNe":    "Dark Nebula",
    "MolCld": "Dark Nebula",
    "CGb":    "Dark Nebula",
    "PN":     "Planetary Nebula",
    "SNR":    "Supernova Remnant",
    "ISM":    "Emission Nebula",
    # Galaxies
    "G":      "Spiral Galaxy",
    "AGN":    "Spiral Galaxy",
    "GiG":    "Irregular Galaxy",
    "GiP":    "Spiral Galaxy",
    "SyG":    "Spiral Galaxy",
    "GGroup": "Spiral Galaxy",
    "GPair":  "Spiral Galaxy",
    "IG":     "Interacting Galaxies",
    "ClG":    "Cluster of Galaxies",
    # Clusters
    "GlC":    "Globular Cluster",
    "OpC":    "Open Cluster",
    "Cl*":    "Open Cluster",
    "Assoc*": "Open Cluster",
    # Stars
    "**":     "Double Star",
    "*":      "Double Star",
}


def objectid_to_simbad_name(object_id):
    """Convert an objectId to a SIMBAD-resolvable identifier string."""
    oid = object_id.lower()
    m = re.match(r'^sh2-(\d+)$', oid)
    if m:
        return f"Sh 2-{m.group(1)}"
    m = re.match(r'^barnard(\d+)$', oid)
    if m:
        return f"Barnard {m.group(1)}"
    m = re.match(r'^ldn(\d+)$', oid)
    if m:
        return f"LDN {m.group(1)}"
    return object_id


def simbad_lookup(object_id):
    """Query SIMBAD for a single object. Returns a result dict or None."""
    name = objectid_to_simbad_name(object_id)
    try:
        result = _simbad.query_object(name)
    except Exception as e:
        print(f"  SIMBAD error for {name!r}: {e}")
        return None
    if result is None or len(result) == 0:
        return None

    row = result[0]

    try:
        ra = float(row["ra"])
    except Exception:
        ra = None
    try:
        dec = float(row["dec"])
    except Exception:
        dec = None

    raw_type = str(row["otype"]).strip() if row["otype"] else ""
    sub_type = SIMBAD_TYPE_MAP.get(raw_type)

    return {
        "objectId":         object_id,
        "ra":               ra,
        "dec":              dec,
        "constellation":    None,
        "subType":          sub_type,
        "magnitude":        None,
        "angularSizeMajor": None,
        "angularSizeMinor": None,
        "_simbad_name":     name,
        "_simbad_type":     raw_type,
    }


print("SIMBAD fallback configured.")
# Out:
# SIMBAD fallback configured.

# %%
# Cell 5b — Perform lookups

# Aliases: objectId → NGC/IC name for objects whose Messier number isn't in OpenNGC's M column.
OPENGC_NAME_ALIASES = {
    "m102": "NGC5866",   # M102 conventionally = NGC 5866 (Spindle Galaxy)
}

# Manual data: last-resort fallback for objects that can't be resolved programmatically.
# RA/Dec in decimal degrees. Angular sizes in arcminutes.
MANUAL_DATA = {
    # Whale and Hockey Stick Galaxies — non-standard objectId
    "whalehockey": {
        "ra": 190.725, "dec": 32.349, "constellation": "Canes Venatici",
        "subType": "Galaxy Group", "magnitude": None,
        "angularSizeMajor": 86.0, "angularSizeMinor": 58.0,
    },    
    # M106 and NGC 2417 — non-standard objectId
    "m106ngc4217": {
        "ra": 184.325, "dec": 47.1939, "constellation": "Canes Venatici",
        "subType": "Galaxy Group", "magnitude": None,
        "angularSizeMajor": 86.0, "angularSizeMinor": 58.0,
    },    
    # Bode's and Cigar — non-standard objectId
    "m81m82": {
        "ra": 148.9958, "dec": 69.3292, "constellation": "Ursa Major",
        "subType": "Galaxy Group", "magnitude": None,
        "angularSizeMajor": 52.0, "angularSizeMinor": 35.0,
    },    
    # Leo Triplete — non-standard objectId
    "leotriplet": {
        "ra": 169.963, "dec": 13.280, "constellation": "Leo",
        "subType": "Galaxy Group", "magnitude": None,
        "angularSizeMajor": 48.0, "angularSizeMinor": 30.0,
    },
    # Markarian — non-standard objectId
    "markarian": {
        "ra": 186.658, "dec": 12.9367, "constellation": "Virgo",
        "subType": "Galaxy Group", "magnitude": None,
        "angularSizeMajor": 90.0, "angularSizeMinor": 30.0,
    },
    # Rho Oph — non-standard objectId, SIMBAD won't match "rhoophiuchi"
    "rhoophiuchi": {
        "ra": 246.396, "dec": -23.45, "constellation": "Oph",
        "subType": "Emission Nebula", "magnitude": None,
        "angularSizeMajor": 270.0, "angularSizeMinor": 270.0,
    },
}


def extract_row_data(row, oid):
    ra  = parse_ra_degrees(row.get("RA", ""))
    dec = parse_dec_degrees(row.get("Dec", ""))

    raw_type = row.get("Type", "").strip()
    sub_type = OPENGC_TYPE_MAP.get(raw_type)

    hubble = row.get("Hubble", "").strip()
    if sub_type in ("Spiral Galaxy", "Elliptical Galaxy", "Lenticular Galaxy") and hubble:
        if hubble.startswith("SB"):
            sub_type = "Barred Spiral Galaxy"
        elif hubble.startswith("S0") or hubble == "S0":
            sub_type = "Lenticular Galaxy"
        elif hubble.startswith("S"):
            sub_type = "Spiral Galaxy"
        elif hubble.startswith("E"):
            sub_type = "Elliptical Galaxy"
        elif hubble.startswith("Irr") or hubble.startswith("I"):
            sub_type = "Irregular Galaxy"

    try:
        mag = float(row.get("V-Mag") or row.get("B-Mag") or "")
    except (ValueError, KeyError):
        mag = None

    try:
        size_major = float(row.get("MajAx", ""))
    except (ValueError, KeyError):
        size_major = None

    try:
        size_minor = float(row.get("MinAx", ""))
    except (ValueError, KeyError):
        size_minor = None

    constellation = row.get("Const", "").strip() or None

    return {
        "objectId":         oid,
        "ra":               ra,
        "dec":              dec,
        "constellation":    constellation,
        "subType":          sub_type,
        "magnitude":        mag,
        "angularSizeMajor": size_major,
        "angularSizeMinor": size_minor,
    }


lookup_results = []
not_found = []
simbad_hits = []

for obj in objects:
    oid = obj["objectId"]
    row = None

    # 1. OpenNGC by NGC/IC name
    opengc_name = object_id_to_opengc_name(oid)
    if opengc_name and opengc_name in opengc_lookup:
        row = opengc_lookup[opengc_name]

    # 2. OpenNGC by Messier number
    if row is None:
        oid_lower = oid.lower()
        if oid_lower.startswith("m") and oid_lower[1:].isdigit():
            row = messier_lookup.get(int(oid_lower[1:]))

    # 3. OpenNGC via alias (e.g. m102 → NGC5866)
    if row is None:
        alias = OPENGC_NAME_ALIASES.get(oid.lower())
        if alias:
            alias_name = object_id_to_opengc_name(alias) or alias
            row = opengc_lookup.get(alias_name)

    if row is not None:
        lookup_results.append(extract_row_data(row, oid))
        continue

    # 4. Manual data — checked before SIMBAD so a partial SIMBAD result never
    #    overrides an intentional manual entry (e.g. object resolves but lacks type/size).
    if oid.lower() in MANUAL_DATA:
        lookup_results.append({"objectId": oid, **MANUAL_DATA[oid.lower()]})
        continue

    # 5. SIMBAD fallback — small delay between requests to avoid rate limiting
    time.sleep(0.5)
    print(f"  SIMBAD: querying {oid}...")
    result = simbad_lookup(oid)
    if result is not None:
        simbad_hits.append(f"{oid} → {result['_simbad_name']} ({result['_simbad_type']})")
        result.pop("_simbad_name", None)
        result.pop("_simbad_type", None)
        lookup_results.append(result)
        continue

    # 6. Not found
    not_found.append(oid)
    lookup_results.append({"objectId": oid, "ra": None, "dec": None,
                            "constellation": None, "subType": None,
                            "magnitude": None, "angularSizeMajor": None,
                            "angularSizeMinor": None})

print(f"\nLooked up: {len(lookup_results) - len(not_found)}/{len(objects)}")
if simbad_hits:
    print(f"\nSIMBAD resolved {len(simbad_hits)} objects:")
    for h in simbad_hits:
        print(f"  {h}")
if not_found:
    print(f"\nNot found anywhere: {not_found}")
# Out:
#   SIMBAD: querying abell1060...
#   SIMBAD: querying sh2-261...
#   SIMBAD: querying sh2-112...
#   SIMBAD: querying sh2-101...
#   SIMBAD: querying sh2-157...
#   SIMBAD: querying sh2-155...
#   SIMBAD: querying sh2-132...
#   SIMBAD: querying sh2-308...
#   SIMBAD: querying wr134...
#   SIMBAD: querying sh2-223...
#   SIMBAD: querying sh2-224...
#   SIMBAD: querying sh2-274...
#   SIMBAD: querying sh2-188...
#   SIMBAD: querying sh2-240...
#   SIMBAD: querying barnard72...
#   SIMBAD: querying ldn1082...
#   SIMBAD: querying m40...
#   SIMBAD: querying m45...
#
# Looked up: 176/176
#
# SIMBAD resolved 18 objects:
#   abell1060 → abell1060 (ClG)
#   sh2-261 → Sh 2-261 (HII)
#   sh2-112 → Sh 2-112 (HII)
#   sh2-101 → Sh 2-101 (HII)
#   sh2-157 → Sh 2-157 (HII)
#   sh2-155 → Sh 2-155 (HII)
#   sh2-132 → Sh 2-132 (HII)
#   sh2-308 → Sh 2-308 (WR*)
#   wr134 → wr134 (WR*)
#   sh2-223 → Sh 2-223 (HII)
#   sh2-224 → Sh 2-224 (HII)
#   sh2-274 → Sh 2-274 (PN)
#   sh2-188 → Sh 2-188 (PN)
# ...

# %%
# Cell 6 — Build & validate DataFrame

# Build base DataFrame from object list
base_df = pd.DataFrame(objects)

# Merge with lookup results
lookup_df = pd.DataFrame(lookup_results)
df = base_df.merge(lookup_df, on="objectId", how="left")

# Apply subType overrides
for oid, override_subtype in SUBTYPE_OVERRIDES.items():
    mask = df["objectId"] == oid
    df.loc[mask, "subType"] = override_subtype

# Derive type from subType
df["type"] = df["subType"].map(SUBTYPE_TO_TYPE)

# Expand constellation abbreviations to full names
df["constellation"] = df["constellation"].map(
    lambda abbr: CONSTELLATION_NAMES.get(abbr, abbr) if pd.notna(abbr) else None
)

# Fill missing constellations from RA/Dec using IAU boundaries
def constellation_from_coords(row):
    if pd.notna(row["constellation"]):
        return row["constellation"]
    if pd.isna(row["ra"]) or pd.isna(row["dec"]):
        return None
    coord = SkyCoord(ra=row["ra"] * u.degree, dec=row["dec"] * u.degree)
    return get_constellation(coord)

df["constellation"] = df.apply(constellation_from_coords, axis=1)

# ── Validation ──
errors = []

# 1. Missing RA/Dec
missing_coords = df[df["ra"].isna() | df["dec"].isna()]["objectId"].tolist()
if missing_coords:
    errors.append(f"Missing ra/dec for: {missing_coords}")

# 2. Unmapped subTypes
unmapped = df[df["type"].isna() & df["subType"].notna()][["objectId", "subType"]].drop_duplicates()
if not unmapped.empty:
    errors.append(f"Unmapped subTypes — add to SUBTYPE_TO_TYPE:\n{unmapped.to_string(index=False)}")

# 3. Null subType (not found anywhere and no override)
null_subtype = df[df["subType"].isna()]["objectId"].tolist()
if null_subtype:
    errors.append(f"No subType resolved (not in OpenNGC, no override): {null_subtype}")

# 4. Duplicate objectIds
dupes = df[df.duplicated("objectId")]["objectId"].tolist()
if dupes:
    errors.append(f"Duplicate objectIds: {dupes}")

if errors:
    raise ValueError("Validation failed:\n" + "\n".join(errors))

print(f"Validation passed. {len(df)} objects ready.")
df[["displayName", "objectId", "type", "subType", "constellation", "ra", "dec",
    "angularSizeMajor", "angularSizeMinor", "magnitude", "recommended"]]
# Out:
# Validation passed. 176 objects ready.
#                         displayName    objectId     type  \
# 0    Double Cluster (NGC 869 & 884)      ngc869  cluster
# 1                       Leo Triplet  leotriplet   galaxy
# 2                 Markarian's Chain   markarian   galaxy
# 3         Bode's and Cigar Galaxies      m81m82   galaxy
# 4                  Hamburger Galaxy     ngc3628   galaxy
# ..                              ...         ...      ...
# 171                            M106        m106   galaxy
# 172                            M107        m107  cluster
# 173                            M108        m108   galaxy
# 174                            M109        m109   galaxy
# 175                            M110        m110   galaxy
#
#                   subType   constellation          ra        dec  \
# 0            Open Cluster         Perseus   34.744000  57.117250
# 1            Galaxy Group             Leo  169.963000  13.280000
# ...

# %%
# Cell 6b — Full table view for visual verification
import pandas as pd

pd.set_option("display.max_rows", 200)
pd.set_option("display.max_colwidth", 40)
pd.set_option("display.width", 120)

df[["displayName", "objectId", "type", "subType", "constellation", "ra", "dec",
    "angularSizeMajor", "angularSizeMinor", "magnitude", "recommended"]]
# Out:
#                                  displayName     objectId     type               subType     constellation  \
# 0             Double Cluster (NGC 869 & 884)       ngc869  cluster          Open Cluster           Perseus
# 1                                Leo Triplet   leotriplet   galaxy          Galaxy Group               Leo
# 2                          Markarian's Chain    markarian   galaxy          Galaxy Group             Virgo
# 3                  Bode's and Cigar Galaxies       m81m82   galaxy          Galaxy Group        Ursa Major
# 4                           Hamburger Galaxy      ngc3628   galaxy  Barred Spiral Galaxy               Leo
# 5             The Hydra Cluster (Abell 1060)    abell1060   galaxy   Cluster of Galaxies             Hydra
# 6                         M106 with NGC 4217  m106ngc4217   galaxy          Galaxy Group    Canes Venatici
# 7    Whale (NGC 4631) & Hockey Stick (NGC...  whalehockey   galaxy          Galaxy Group    Canes Venatici
# ...

# %%
# Cell 7 — Serialize to dso.json
# RA is stored in decimal hours (divide degrees by 15) to match the app's expected format.

output_cols = [
    "displayName",
    "objectId",
    "ra",
    "dec",
    "type",
    "subType",
    "constellation",
    "recommended",
    "angularSizeMajor",
    "angularSizeMinor",
    "magnitude",
]

out_df = df[output_cols].copy()
out_df["ra"] = (out_df["ra"] / 15).round(7)

out_df.to_json(OUTPUT_FILE, orient="records", indent=2)
print(f"Written {len(out_df)} objects to {OUTPUT_FILE}")
# Out:
# Written 176 objects to mobile/dso.json
